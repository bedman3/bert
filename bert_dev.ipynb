# %%
import pandas as pd

# %%
train_df = pd.read_csv('data/train.csv')
validate_df = pd.read_csv('data/valid.csv')

# %%
train_df
# Out:
#                   business_id  cool                 date  funny  \
# 0      4wjJe3AxFyVOSMHLRh68Og     8  2009-08-22 21:06:56     10
# 1      xGXzIliuZ6FgMS870UjPRw     0  2017-08-24 16:53:53      0
# 2      wdwODzBChLIh_u8V8CPpyA     0  2014-08-15 02:31:54      0
# 3      n8Zqqhff-2cxzWt_nwhU2Q     1  2015-06-30 03:48:18      1
# 4      Em2ZuYiyTr4_ITSCTi86CQ     0  2018-05-25 22:29:25      0
# ...                       ...   ...                  ...    ...
# 19995  aLdMqYoHqc77JjOybdPX-A     0  2013-11-20 22:33:16      0
# 19996  9n8jDTvkOjoH3fD_Y9KC1g     0  2015-02-01 23:22:31      3
# 19997  K-HCIVG4ZWjDaSMAuGAW7A     0  2012-08-30 22:28:10      1
# 19998  pQ6hEVe7KPw28W07Lcoc8A     0  2010-01-07 01:03:31      0
# 19999  7xfeQhen2wLnvFuQNvmTAg     1  2016-02-01 15:58:15      3
#
#                     review_id  stars  \
# 0      ygjO-o4_YoXr41D7Rx9vmw      4
# 1      MN5bVycm01xc7V3PPBPoMQ      5
# 2      9eDWY5cevgRhywg6uTm8Pw      2
# 3      Zt9Yj5K1Y-MnDmocXI9Zgw      5
# ...

# %%
validate_df
# Out:
#                  business_id  cool                 date  funny  \
# 0     eYE7zd30ltLAS1V3ssdtrQ     1  2018-07-19 00:36:11      0
# 1     o5QDrg_kb4hgsWxV6cV_Uw     0  2017-02-04 17:12:38      0
# 2     2H7An6VjETD-CYFNyXx1NA     0  2015-08-04 18:05:10      0
# 3     Tx577Vb4SeYxppiRIo3SKQ     0  2015-02-27 02:23:06      0
# 4     e6UDJBEIoXBbnXtdwkqIGA     4  2016-03-08 04:35:04     14
# ...                      ...   ...                  ...    ...
# 1995  tn1gKZnoYs97DyxBhP-QVA     0  2018-07-16 21:33:53      0
# 1996  rphZ0RuQ120z3uJX6dRJ2g     0  2018-08-24 22:02:38      0
# 1997  -kIscN8I29eXMPkvyyxmRQ     0  2017-11-19 19:55:01      0
# 1998  9zvglUorc3YOpN3SyJQKZw     0  2015-11-15 20:17:24      0
# 1999  OWll9a5nBADV25pAFh7wPw     0  2013-12-12 20:09:39      0
#
#                    review_id  stars  \
# 0     ewaMkuxfjfCX3ndtk0oRTw      4
# 1     SzkuvIpf0lcVaDgk5x2ipg      5
# 2     ZGg6emL3sqhyyqHD_DJEag      5
# 3     IXYLmBVvRVFJZEhnhE_YsQ      5
# ...
